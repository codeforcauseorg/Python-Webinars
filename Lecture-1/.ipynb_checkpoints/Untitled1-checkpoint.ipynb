# %%
a = 10.3

# %%
type(a)
# Out:
# float

# %%
# size

# %%
a = 23456789876543234567890987654321234567

# %%
type(a)
# Out:
# int

# %%
b = a ** 100

# %%
type(b)
# Out:
# int

# %%
c = b ** 100

# %%
type(c)
# Out:
# int
