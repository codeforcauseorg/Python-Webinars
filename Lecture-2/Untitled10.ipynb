# %%
# closures

# %%
def outer_func():
    message = "hi"
    
    def inner_func():
        print(locals())
        print(message) # free variable
    
    return inner_func

# %%
my_func = outer_func() # my_func = inner_func

# %%
my_func()
# Out:
# {'message': 'hi'}
# hi

# %%
def make_multi(n):
    def multiplier(x):
        print(locals())
        return x * n
    return multiplier

# %%
times2 = make_multi(2)

# %%
times3 = make_multi(3)

# %%
times3(9)
# Out:
# {'x': 9, 'n': 3}
# 27
